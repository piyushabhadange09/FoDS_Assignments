# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
heart_dis=pd.read_csv("C:/Users/Lenovo/Desktop/jupyter notebook/dataset/heart.csv")
heart_dis
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
heart_dis.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
heart_dis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
heart_dis.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
heart_dis.describe(include='object')
# Out:
#         Sex ChestPainType RestingECG ExerciseAngina ST_Slope
# count   918           918        918            918      918
# unique    2             4          3              2        3
# top       M           ASY     Normal              N     Flat
# freq    725           496        552            547      460

# %%
sns.distplot(heart_dis["RestingBP"])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17896\1696134414.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(heart_dis["RestingBP"])
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
heart_dis["RestingBP"]=heart_dis["RestingBP"].replace(0,heart_dis["RestingBP"].mean())

# %%
heart_dis.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.540737   198.799564    0.233115  136.809368
# std      9.432617   17.989932   109.384145    0.423046   25.460334
# min     28.000000   80.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
sns.distplot(heart_dis["Cholesterol"])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17896\969394549.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(heart_dis["Cholesterol"])
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
heart_dis["Cholesterol"]=heart_dis["Cholesterol"].replace(0,heart_dis["Cholesterol"].mean())

# %%
heart_dis.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.540737   236.047413    0.233115  136.809368
# std      9.432617   17.989932    56.240952    0.423046   25.460334
# min     28.000000   80.000000    85.000000    0.000000   60.000000
# 25%     47.000000  120.000000   198.799564    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
sns.countplot(x='Sex',hue='HeartDisease',data=heart_dis)
plt.title("Comparisions of Heart diseases with respective to the gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #Male suffers the Heart Disease more than females.

# %%
heart_dis.groupby("ChestPainType").size().plot(kind='pie',autopct="%0.2f")
# Out:
# <Axes: >

# %%
heart_dis.groupby("RestingECG").size().plot(kind='pie',autopct="%0.2f")
# Out:
# <Axes: >

# %%
heart_dis.groupby("ExerciseAngina").size().plot(kind='pie',autopct="%0.2f")
# Out:
# <Axes: >

# %%
heart_dis.groupby("ST_Slope").size().plot(kind='pie',autopct="%0.2f")
# Out:
# <Axes: >

# %%
sns.displot(heart_dis,x="Age",hue="HeartDisease")
#People having age greater than 60 have more problems of Heart Disease

# %%
sns.heatmap(heart_dis.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
heart_dis.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA      140.0        289.0          0     Normal    172
# 1   49   F           NAP      160.0        180.0          0     Normal    156
# 2   37   M           ATA      130.0        283.0          0         ST     98
# 3   48   F           ASY      138.0        214.0          0     Normal    108
# 4   54   M           NAP      150.0        195.0          0     Normal    122
# 5   39   M           NAP      120.0        339.0          0     Normal    170
# 6   45   F           ATA      130.0        237.0          0     Normal    170
# 7   54   M           ATA      110.0        208.0          0     Normal    142
# 8   37   M           ASY      140.0        207.0          0     Normal    130
# 9   48   F           ATA      120.0        284.0          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# ...

# %%
#one hot en
heart_dis= pd.get_dummies(heart_dis, columns=['Sex', 'ChestPainType'], drop_first=True)

# %%
heart_dis
# Out:
#      Age  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR ExerciseAngina  \
# 0     40      140.0        289.0          0     Normal    172              N
# 1     49      160.0        180.0          0     Normal    156              N
# 2     37      130.0        283.0          0         ST     98              N
# 3     48      138.0        214.0          0     Normal    108              Y
# 4     54      150.0        195.0          0     Normal    122              N
# ..   ...        ...          ...        ...        ...    ...            ...
# 913   45      110.0        264.0          0     Normal    132              N
# 914   68      144.0        193.0          1     Normal    141              N
# 915   57      130.0        131.0          0     Normal    115              Y
# 916   57      130.0        236.0          0        LVH    174              N
# 917   38      138.0        175.0          0     Normal    173              N
#
# ...

# %%
sns.boxplot(heart_dis["Cholesterol"])
#Boxplot of Cholesterol
# Out:
# <Axes: ylabel='Cholesterol'>

# %%
#Define a function to remove outliers based on IQR
def remove_outliers_from_boxplot(heart_dis, x):
    Q1 = heart_dis["Cholesterol"].quantile(0.25)
    Q3 = heart_dis["Cholesterol"].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return heart_dis[(heart_dis["Cholesterol"] >= lower_bound) & (heart_dis["Cholesterol"] <= upper_bound)]

# Apply outlier removal on 'Cholesterol'
heart_dis = remove_outliers_from_boxplot(heart_dis, 'Cholesterol')

# %%
sns.boxplot(heart_dis["Cholesterol"])
#outliers has been removed from Cholesterol
# Out:
# <Axes: ylabel='Cholesterol'>

# %%
sns.boxplot(heart_dis["RestingBP"])
#Boxplot of RestingBP
# Out:
# <Axes: ylabel='RestingBP'>

# %%
def remove_outliers_from_boxplot(heart_dis, x):
    Q1 = heart_dis["RestingBP"].quantile(0.25)
    Q3 =heart_dis["RestingBP"].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return heart_dis[(heart_dis["RestingBP"] >= lower_bound) & (heart_dis["RestingBP"] <= upper_bound)]

# Apply outlier removal on 'Cholesterol'
heart_dis= remove_outliers_from_boxplot(heart_dis, 'RestingBP')

# %%
sns.boxplot(heart_dis["RestingBP"])
#Outliers has been removed
# Out:
# <Axes: ylabel='RestingBP'>

# %%
sns.boxplot(heart_dis["Oldpeak"])
# Out:
# <Axes: ylabel='Oldpeak'>

# %%
def remove_outliers_from_boxplot(heart_dis, x):
    Q1 = heart_dis["Oldpeak"].quantile(0.25)
    Q3 =heart_dis["Oldpeak"].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return heart_dis[(heart_dis["Oldpeak"] >= lower_bound) & (heart_dis["Oldpeak"] <= upper_bound)]

# Apply outlier removal on 'Cholesterol'
heart_dis= remove_outliers_from_boxplot(heart_dis, 'Oldpeak')

# %%
sns.boxplot(heart_dis["Oldpeak"])
#outliers form Oldpeak has been removed
# Out:
# <Axes: ylabel='Oldpeak'>

# %%
#cleaned and transformed data
heart_dis
# Out:
#      Age  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR ExerciseAngina  \
# 0     40      140.0        289.0          0     Normal    172              N
# 1     49      160.0        180.0          0     Normal    156              N
# 2     37      130.0        283.0          0         ST     98              N
# 3     48      138.0        214.0          0     Normal    108              Y
# 4     54      150.0        195.0          0     Normal    122              N
# ..   ...        ...          ...        ...        ...    ...            ...
# 913   45      110.0        264.0          0     Normal    132              N
# 914   68      144.0        193.0          1     Normal    141              N
# 915   57      130.0        131.0          0     Normal    115              Y
# 916   57      130.0        236.0          0        LVH    174              N
# 917   38      138.0        175.0          0     Normal    173              N
#
# ...
